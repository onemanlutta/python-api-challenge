# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
# url = # YOUR CODE HERE
url = "http://api.openweathermap.org/data/2.5/weather?"



# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    # city_url = # YOUR CODE HERE
    city_url = url  + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        # city_weather = # YOUR CODE HERE
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        # city_lat = # YOUR CODE HERE
        city_lat = city_weather['coord']['lat']

        city_lng = city_weather['coord']['lon']

        # convert Kelvin into Celsius is C = K - 273.15
        city_max_temp = city_weather['main']['temp_max'] - 273.15
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gweru
# Processing Record 2 of Set 1 | palmer
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | kencong
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 10 of Set 1 | hanover
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | edinburgh of the seven seas
# Processing Record 13 of Set 1 | sandwip
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | nolinsk
# Processing Record 17 of Set 1 | mahina
# Processing Record 18 of Set 1 | uddevalla
# Processing Record 19 of Set 1 | ola
# Processing Record 20 of Set 1 | ishigaki
# Processing Record 21 of Set 1 | tsiombe
# Processing Record 22 of Set 1 | sastre
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | margaret river
# Processing Record 25 of Set 1 | cadale
# Processing Record 26 of Set 1 | alofi
# Processing Record 27 of Set 1 | chonchi
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | ovalle
# Processing Record 30 of Set 1 | hamilton
# Processing Record 31 of Set 1 | smithers
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | kerikeri
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | coquimbo
# Processing Record 36 of Set 1 | stanley
# Processing Record 37 of Set 1 | ghat
# Processing Record 38 of Set 1 | chibougamau
# Processing Record 39 of Set 1 | svetlyy
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | blackmans bay
# Processing Record 43 of Set 1 | puerto natales
# Processing Record 44 of Set 1 | eyl
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | kharp
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | kununurra
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | hawaiian paradise park
# Processing Record 0 of Set 2 | mamou
# Processing Record 1 of Set 2 | ilulissat
# Processing Record 2 of Set 2 | omamacho-omama
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | new plymouth
# Processing Record 5 of Set 2 | nemuro
# Processing Record 6 of Set 2 | paramonga
# Processing Record 7 of Set 2 | birjand
# Processing Record 8 of Set 2 | kingston
# Processing Record 9 of Set 2 | queenstown
# Processing Record 10 of Set 2 | tres lagoas
# Processing Record 11 of Set 2 | minbu
# Processing Record 12 of Set 2 | sitka
# Processing Record 13 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 14 of Set 2 | ajaccio
# Processing Record 15 of Set 2 | anadyr
# Processing Record 16 of Set 2 | itaituba
# Processing Record 17 of Set 2 | khandyga
# Processing Record 18 of Set 2 | invercargill
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | bilibino
# Processing Record 23 of Set 2 | college
# Processing Record 24 of Set 2 | papatowai
# Processing Record 25 of Set 2 | salalah
# Processing Record 26 of Set 2 | praia da vitoria
# Processing Record 27 of Set 2 | vitorino freire
# Processing Record 28 of Set 2 | takikawa
# Processing Record 29 of Set 2 | shaffa
# Processing Record 30 of Set 2 | qamdo
# Processing Record 31 of Set 2 | esfarayen
# Processing Record 32 of Set 2 | suva
# Processing Record 33 of Set 2 | sisimiut
# Processing Record 34 of Set 2 | lihue
# Processing Record 35 of Set 2 | altamira
# Processing Record 36 of Set 2 | zalingei
# Processing Record 37 of Set 2 | daru
# Processing Record 38 of Set 2 | flin flon
# Processing Record 39 of Set 2 | west island
# Processing Record 40 of Set 2 | tazovsky
# Processing Record 41 of Set 2 | dongola
# Processing Record 42 of Set 2 | hovd
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | kolonia town
# Processing Record 45 of Set 2 | geraldton
# Processing Record 46 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 47 of Set 2 | tazacorte
# Processing Record 48 of Set 2 | solikamsk
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 0 of Set 3 | lebu
# Processing Record 1 of Set 3 | la passe
# Processing Record 2 of Set 3 | kulia village
# City not found. Skipping...
# Processing Record 3 of Set 3 | qaqortoq
# Processing Record 4 of Set 3 | ancud
# Processing Record 5 of Set 3 | arrifes
# Processing Record 6 of Set 3 | nishinoomote
# Processing Record 7 of Set 3 | erenhot
# Processing Record 8 of Set 3 | saipan
# Processing Record 9 of Set 3 | three points
# Processing Record 10 of Set 3 | atafu village
# Processing Record 11 of Set 3 | heishan
# Processing Record 12 of Set 3 | wailua homesteads
# Processing Record 13 of Set 3 | port mathurin
# Processing Record 14 of Set 3 | lompoc
# Processing Record 15 of Set 3 | waitangi
# Processing Record 16 of Set 3 | afaahiti
# Processing Record 17 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 18 of Set 3 | simanggang
# Processing Record 19 of Set 3 | udachny
# Processing Record 20 of Set 3 | farap
# Processing Record 21 of Set 3 | huangshan
# Processing Record 22 of Set 3 | quepos
# Processing Record 23 of Set 3 | morondava
# Processing Record 24 of Set 3 | pregradnaya
# Processing Record 25 of Set 3 | minas de matahambre
# City not found. Skipping...
# Processing Record 26 of Set 3 | raduzhny
# Processing Record 27 of Set 3 | champerico
# Processing Record 28 of Set 3 | kidal
# Processing Record 29 of Set 3 | olonkinbyen
# Processing Record 30 of Set 3 | las piedras
# Processing Record 31 of Set 3 | egilsstadir
# Processing Record 32 of Set 3 | hilo
# Processing Record 33 of Set 3 | magadan
# Processing Record 34 of Set 3 | sechura
# Processing Record 35 of Set 3 | maiwut
# City not found. Skipping...
# Processing Record 36 of Set 3 | kourou
# Processing Record 37 of Set 3 | lorengau
# Processing Record 38 of Set 3 | lazaro cardenas
# Processing Record 39 of Set 3 | luderitz
# Processing Record 40 of Set 3 | puerto rico
# Processing Record 41 of Set 3 | gallivare
# City not found. Skipping...
# Processing Record 42 of Set 3 | leava
# Processing Record 43 of Set 3 | levuka
# Processing Record 44 of Set 3 | toliara
# Processing Record 45 of Set 3 | hotan
# Processing Record 46 of Set 3 | saint-joseph
# Processing Record 47 of Set 3 | kuzovatovo
# Processing Record 48 of Set 3 | salekhard
# Processing Record 49 of Set 3 | uturoa
# Processing Record 0 of Set 4 | amos
# Processing Record 1 of Set 4 | quellon
# Processing Record 2 of Set 4 | bandon
# Processing Record 3 of Set 4 | kodiak
# Processing Record 4 of Set 4 | owando
# Processing Record 5 of Set 4 | mingelchaur
# Processing Record 6 of Set 4 | bani walid
# Processing Record 7 of Set 4 | beli
# Processing Record 8 of Set 4 | shimoda
# Processing Record 9 of Set 4 | talakan
# Processing Record 10 of Set 4 | al hazm
# Processing Record 11 of Set 4 | utrik
# Processing Record 12 of Set 4 | nova sintra
# Processing Record 13 of Set 4 | san luis de la loma
# Processing Record 14 of Set 4 | mili
# Processing Record 15 of Set 4 | nchelenge
# Processing Record 16 of Set 4 | aasiaat
# Processing Record 17 of Set 4 | bandar lampung
# Processing Record 18 of Set 4 | hasaki
# Processing Record 19 of Set 4 | karabar
# Processing Record 20 of Set 4 | calvinia
# Processing Record 21 of Set 4 | tabou
# Processing Record 22 of Set 4 | mramani
# Processing Record 23 of Set 4 | boa vista
# Processing Record 24 of Set 4 | weno
# Processing Record 25 of Set 4 | panadura
# Processing Record 26 of Set 4 | sandnessjoen
# Processing Record 27 of Set 4 | richards bay
# Processing Record 28 of Set 4 | isafjordur
# Processing Record 29 of Set 4 | paracuru
# Processing Record 30 of Set 4 | pochinki
# Processing Record 31 of Set 4 | acarau
# Processing Record 32 of Set 4 | khovd
# Processing Record 33 of Set 4 | baardheere
# Processing Record 34 of Set 4 | san ignacio
# Processing Record 35 of Set 4 | lovington
# Processing Record 36 of Set 4 | aykhal
# Processing Record 37 of Set 4 | westport
# Processing Record 38 of Set 4 | fortuna
# Processing Record 39 of Set 4 | fort mcmurray
# Processing Record 40 of Set 4 | hammerfest
# Processing Record 41 of Set 4 | mitsamiouli
# Processing Record 42 of Set 4 | la gi
# Processing Record 43 of Set 4 | vicosa
# Processing Record 44 of Set 4 | ataq
# Processing Record 45 of Set 4 | muisne
# Processing Record 46 of Set 4 | borzna
# Processing Record 47 of Set 4 | ust-nera
# Processing Record 48 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 49 of Set 4 | okha
# Processing Record 0 of Set 5 | tha khanon
# Processing Record 1 of Set 5 | hami
# Processing Record 2 of Set 5 | vuktyl
# Processing Record 3 of Set 5 | linqiong
# Processing Record 4 of Set 5 | olmos
# Processing Record 5 of Set 5 | lethem
# Processing Record 6 of Set 5 | ain sefra
# Processing Record 7 of Set 5 | dudinka
# Processing Record 8 of Set 5 | yuzhno-kurilsk
# Processing Record 9 of Set 5 | mount pearl
# Processing Record 10 of Set 5 | talnakh
# Processing Record 11 of Set 5 | abilene
# Processing Record 12 of Set 5 | pagar alam
# Processing Record 13 of Set 5 | sydney
# Processing Record 14 of Set 5 | kertih
# Processing Record 15 of Set 5 | vernon
# Processing Record 16 of Set 5 | codrington
# Processing Record 17 of Set 5 | cheremukhovo
# Processing Record 18 of Set 5 | roma
# Processing Record 19 of Set 5 | ciudad lazaro cardenas
# Processing Record 20 of Set 5 | cavalaire-sur-mer
# Processing Record 21 of Set 5 | dunedin
# Processing Record 22 of Set 5 | akureyri
# Processing Record 23 of Set 5 | vadso
# Processing Record 24 of Set 5 | santa marta
# Processing Record 25 of Set 5 | mount isa
# Processing Record 26 of Set 5 | labrador city
# Processing Record 27 of Set 5 | karratha
# Processing Record 28 of Set 5 | cidreira
# Processing Record 29 of Set 5 | grenaa
# Processing Record 30 of Set 5 | mahbubabad
# Processing Record 31 of Set 5 | haiku-pauwela
# Processing Record 32 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 33 of Set 5 | peterhead
# Processing Record 34 of Set 5 | fale old settlement
# Processing Record 35 of Set 5 | vorgashor
# Processing Record 36 of Set 5 | mount gambier
# Processing Record 37 of Set 5 | shajapur
# Processing Record 38 of Set 5 | uaboe
# City not found. Skipping...
# Processing Record 39 of Set 5 | santa cruz
# Processing Record 40 of Set 5 | barcelos
# Processing Record 41 of Set 5 | quebo
# Processing Record 42 of Set 5 | kangding
# Processing Record 43 of Set 5 | ribeira brava
# Processing Record 44 of Set 5 | hithadhoo
# Processing Record 45 of Set 5 | callao
# Processing Record 46 of Set 5 | tsementnyy
# Processing Record 47 of Set 5 | brookings
# Processing Record 48 of Set 5 | jetpur
# Processing Record 49 of Set 5 | kariba
# Processing Record 0 of Set 6 | vilyuchinsk
# Processing Record 1 of Set 6 | jiuquan
# Processing Record 2 of Set 6 | tocopilla
# Processing Record 3 of Set 6 | hobyo
# Processing Record 4 of Set 6 | ivdel'
# Processing Record 5 of Set 6 | huarmey
# Processing Record 6 of Set 6 | castillos
# Processing Record 7 of Set 6 | tibana
# Processing Record 8 of Set 6 | murzuq
# Processing Record 9 of Set 6 | omidiyeh
# Processing Record 10 of Set 6 | naze
# Processing Record 11 of Set 6 | casper
# Processing Record 12 of Set 6 | carnarvon
# Processing Record 13 of Set 6 | susuman
# Processing Record 14 of Set 6 | chadron
# Processing Record 15 of Set 6 | tamarin
# Processing Record 16 of Set 6 | puerto baquerizo moreno
# Processing Record 17 of Set 6 | timaru
# Processing Record 18 of Set 6 | manokwari
# Processing Record 19 of Set 6 | kiunga
# Processing Record 20 of Set 6 | krasnyy chikoy
# Processing Record 21 of Set 6 | rongelap
# Processing Record 22 of Set 6 | youhao
# Processing Record 23 of Set 6 | broken hill
# Processing Record 24 of Set 6 | rawson
# Processing Record 25 of Set 6 | klyuchi
# Processing Record 26 of Set 6 | alice springs
# Processing Record 27 of Set 6 | rybnaya sloboda
# Processing Record 28 of Set 6 | abalak
# Processing Record 29 of Set 6 | pailin
# Processing Record 30 of Set 6 | savave village
# City not found. Skipping...
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | mizdah
# Processing Record 33 of Set 6 | buchach
# Processing Record 34 of Set 6 | altay
# Processing Record 35 of Set 6 | wynyard
# Processing Record 36 of Set 6 | jackson
# Processing Record 37 of Set 6 | kataragama
# City not found. Skipping...
# Processing Record 38 of Set 6 | calabozo
# Processing Record 39 of Set 6 | chaparral
# Processing Record 40 of Set 6 | weligama
# Processing Record 41 of Set 6 | katsuura
# Processing Record 42 of Set 6 | nuevo laredo
# Processing Record 43 of Set 6 | keflavik
# Processing Record 44 of Set 6 | fort bragg
# Processing Record 45 of Set 6 | hengyang
# Processing Record 46 of Set 6 | ceeldheer
# Processing Record 47 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 48 of Set 6 | constantia
# Processing Record 49 of Set 6 | st. john's
# Processing Record 0 of Set 7 | corinto
# Processing Record 1 of Set 7 | kaduna
# Processing Record 2 of Set 7 | aksu
# Processing Record 3 of Set 7 | sorong
# Processing Record 4 of Set 7 | port shepstone
# Processing Record 5 of Set 7 | howard springs
# Processing Record 6 of Set 7 | badger
# Processing Record 7 of Set 7 | kruisfontein
# Processing Record 8 of Set 7 | mandiana
# Processing Record 9 of Set 7 | kepsut
# Processing Record 10 of Set 7 | vila franca do campo
# Processing Record 11 of Set 7 | port saint john's
# Processing Record 12 of Set 7 | san patricio
# Processing Record 13 of Set 7 | katsuren-haebaru
# Processing Record 14 of Set 7 | guia lopes da laguna
# Processing Record 15 of Set 7 | oriximina
# Processing Record 16 of Set 7 | bengkulu
# Processing Record 17 of Set 7 | pamandzi
# Processing Record 18 of Set 7 | belyy yar
# Processing Record 19 of Set 7 | liupanshui
# City not found. Skipping...
# Processing Record 20 of Set 7 | ulysses
# Processing Record 21 of Set 7 | inirida
# Processing Record 22 of Set 7 | dwarka
# Processing Record 23 of Set 7 | kristiansund
# Processing Record 24 of Set 7 | three rivers
# Processing Record 25 of Set 7 | fonte boa
# Processing Record 26 of Set 7 | arteche
# Processing Record 27 of Set 7 | ulladulla
# Processing Record 28 of Set 7 | happy valley-goose bay
# Processing Record 29 of Set 7 | fisterra
# Processing Record 30 of Set 7 | puerto lempira
# Processing Record 31 of Set 7 | kone
# Processing Record 32 of Set 7 | port augusta
# Processing Record 33 of Set 7 | laohekou
# Processing Record 34 of Set 7 | tura
# Processing Record 35 of Set 7 | whitehorse
# Processing Record 36 of Set 7 | 'ain benian
# Processing Record 37 of Set 7 | junin de los andes
# Processing Record 38 of Set 7 | hajjah
# Processing Record 39 of Set 7 | vriddhachalam
# Processing Record 40 of Set 7 | berrotaran
# Processing Record 41 of Set 7 | xinzhi
# Processing Record 42 of Set 7 | gulf shores
# Processing Record 43 of Set 7 | antalaha
# Processing Record 44 of Set 7 | anaconda
# Processing Record 45 of Set 7 | holualoa
# Processing Record 46 of Set 7 | sur
# Processing Record 47 of Set 7 | gilgit
# Processing Record 48 of Set 7 | brisas de zicatela
# Processing Record 49 of Set 7 | kafue
# Processing Record 0 of Set 8 | kill devil hills
# Processing Record 1 of Set 8 | sao tome
# Processing Record 2 of Set 8 | touros
# Processing Record 3 of Set 8 | remire-montjoly
# Processing Record 4 of Set 8 | nago
# Processing Record 5 of Set 8 | guarapari
# Processing Record 6 of Set 8 | ust'-kut
# Processing Record 7 of Set 8 | saint-philippe
# Processing Record 8 of Set 8 | grants pass
# Processing Record 9 of Set 8 | necochea
# Processing Record 10 of Set 8 | ilebo
# Processing Record 11 of Set 8 | non sang
# Processing Record 12 of Set 8 | marupe
# Processing Record 13 of Set 8 | charleston
# Processing Record 14 of Set 8 | pindushi
# Processing Record 15 of Set 8 | nenjiang
# Processing Record 16 of Set 8 | donskoy
# Processing Record 17 of Set 8 | ketchikan
# Processing Record 18 of Set 8 | malvan
# Processing Record 19 of Set 8 | klaksvik
# Processing Record 20 of Set 8 | porto velho
# Processing Record 21 of Set 8 | drayton valley
# Processing Record 22 of Set 8 | emerald
# Processing Record 23 of Set 8 | itoman
# Processing Record 24 of Set 8 | copala
# Processing Record 25 of Set 8 | massawa
# Processing Record 26 of Set 8 | cabo san lucas
# Processing Record 27 of Set 8 | puerto san jose
# Processing Record 28 of Set 8 | new norfolk
# Processing Record 29 of Set 8 | kapa'a
# Processing Record 30 of Set 8 | vila do maio
# Processing Record 31 of Set 8 | draguseni
# Processing Record 32 of Set 8 | oum hadjer
# Processing Record 33 of Set 8 | sealy
# Processing Record 34 of Set 8 | nadym
# Processing Record 35 of Set 8 | yamada
# Processing Record 36 of Set 8 | outapi
# City not found. Skipping...
# Processing Record 37 of Set 8 | guerrero negro
# Processing Record 38 of Set 8 | machilipatnam
# Processing Record 39 of Set 8 | bhor
# Processing Record 40 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 41 of Set 8 | roscommon
# Processing Record 42 of Set 8 | tukrah
# Processing Record 43 of Set 8 | pohang
# Processing Record 44 of Set 8 | timmins
# Processing Record 45 of Set 8 | revda
# Processing Record 46 of Set 8 | saint-pierre
# Processing Record 47 of Set 8 | camapua
# Processing Record 48 of Set 8 | ghardaia
# Processing Record 49 of Set 8 | tolanaro
# Processing Record 0 of Set 9 | khawr fakkan
# Processing Record 1 of Set 9 | tumayr
# Processing Record 2 of Set 9 | posto fiscal rolim de moura
# Processing Record 3 of Set 9 | san antonio de pale
# Processing Record 4 of Set 9 | beloyarskiy
# Processing Record 5 of Set 9 | forster
# Processing Record 6 of Set 9 | viedma
# Processing Record 7 of Set 9 | fuglafjordur
# Processing Record 8 of Set 9 | uliastay
# Processing Record 9 of Set 9 | isla mujeres
# Processing Record 10 of Set 9 | paros
# Processing Record 11 of Set 9 | zhalantun
# Processing Record 12 of Set 9 | rio grande
# Processing Record 13 of Set 9 | shingu
# Processing Record 14 of Set 9 | polyarnyy
# Processing Record 15 of Set 9 | gao
# Processing Record 16 of Set 9 | sunrise manor
# Processing Record 17 of Set 9 | buncrana
# Processing Record 18 of Set 9 | aberdeen
# Processing Record 19 of Set 9 | pisco
# Processing Record 20 of Set 9 | shihezi
# Processing Record 21 of Set 9 | port macquarie
# Processing Record 22 of Set 9 | bereznik
# Processing Record 23 of Set 9 | esmeraldas
# Processing Record 24 of Set 9 | tralee
# Processing Record 25 of Set 9 | kirovskiy
# Processing Record 26 of Set 9 | lingcheng
# Processing Record 27 of Set 9 | sola
# Processing Record 28 of Set 9 | greenland
# Processing Record 29 of Set 9 | stirling
# Processing Record 30 of Set 9 | shache
# Processing Record 31 of Set 9 | enewetak
# Processing Record 32 of Set 9 | gadzhiyevo
# Processing Record 33 of Set 9 | shenjiamen
# Processing Record 34 of Set 9 | ussuriysk
# Processing Record 35 of Set 9 | perryton
# Processing Record 36 of Set 9 | zouerate
# Processing Record 37 of Set 9 | minas de marcona
# Processing Record 38 of Set 9 | manaure balcon del cesar
# Processing Record 39 of Set 9 | usinsk
# Processing Record 40 of Set 9 | san miguel vindho
# Processing Record 41 of Set 9 | bonthe
# Processing Record 42 of Set 9 | lamar
# Processing Record 43 of Set 9 | road town
# Processing Record 44 of Set 9 | kailua-kona
# Processing Record 45 of Set 9 | fort st. john
# Processing Record 46 of Set 9 | raymondville
# Processing Record 47 of Set 9 | le port
# Processing Record 48 of Set 9 | tommot
# Processing Record 49 of Set 9 | pangody
# Processing Record 0 of Set 10 | alghero
# Processing Record 1 of Set 10 | vasind
# Processing Record 2 of Set 10 | mejit
# Processing Record 3 of Set 10 | gebeit
# Processing Record 4 of Set 10 | myaydo
# Processing Record 5 of Set 10 | smara
# Processing Record 6 of Set 10 | dzhetygara
# Processing Record 7 of Set 10 | sosnovo-ozerskoye
# Processing Record 8 of Set 10 | sipocot
# Processing Record 9 of Set 10 | kayangel
# Processing Record 10 of Set 10 | campo formoso
# Processing Record 11 of Set 10 | carbonear
# Processing Record 12 of Set 10 | bridlington
# Processing Record 13 of Set 10 | inari
# Processing Record 14 of Set 10 | kalmunai
# Processing Record 15 of Set 10 | urla
# Processing Record 16 of Set 10 | boca suno
# Processing Record 17 of Set 10 | kailaras
# Processing Record 18 of Set 10 | port isabel
# Processing Record 19 of Set 10 | patong
# Processing Record 20 of Set 10 | kulachi
# Processing Record 21 of Set 10 | libreville
# Processing Record 22 of Set 10 | cabedelo
# Processing Record 23 of Set 10 | newport
# Processing Record 24 of Set 10 | mogadishu
# Processing Record 25 of Set 10 | buurhakaba
# Processing Record 26 of Set 10 | nar'yan-mar
# Processing Record 27 of Set 10 | khoyniki
# Processing Record 28 of Set 10 | novo aripuana
# Processing Record 29 of Set 10 | horizonte
# Processing Record 30 of Set 10 | ulan-ude
# Processing Record 31 of Set 10 | beltran
# Processing Record 32 of Set 10 | sona
# Processing Record 33 of Set 10 | essaouira
# Processing Record 34 of Set 10 | drabiv
# Processing Record 35 of Set 10 | kudahuvadhoo
# Processing Record 36 of Set 10 | tomatlan
# Processing Record 37 of Set 10 | irkutsk
# Processing Record 38 of Set 10 | mabaruma
# Processing Record 39 of Set 10 | kasongo
# Processing Record 40 of Set 10 | azua
# Processing Record 41 of Set 10 | az zuwaytinah
# Processing Record 42 of Set 10 | katabu
# Processing Record 43 of Set 10 | nyala
# Processing Record 44 of Set 10 | kemijarvi
# Processing Record 45 of Set 10 | yerofey pavlovich
# Processing Record 46 of Set 10 | shofirkon shahri
# City not found. Skipping...
# Processing Record 47 of Set 10 | gaoual
# Processing Record 48 of Set 10 | curuca
# Processing Record 49 of Set 10 | penzance
# Processing Record 0 of Set 11 | gbarnga
# Processing Record 1 of Set 11 | nelson bay
# Processing Record 2 of Set 11 | kavaratti
# Processing Record 3 of Set 11 | xinyuan
# Processing Record 4 of Set 11 | la'ie
# Processing Record 5 of Set 11 | red hill
# Processing Record 6 of Set 11 | timimoun
# Processing Record 7 of Set 11 | nantucket
# Processing Record 8 of Set 11 | cockburn town
# Processing Record 9 of Set 11 | choix
# Processing Record 10 of Set 11 | howrah
# Processing Record 11 of Set 11 | belyayevka
# Processing Record 12 of Set 11 | al qadarif
# Processing Record 13 of Set 11 | balikpapan
# Processing Record 14 of Set 11 | aleksandrovsk
# Processing Record 15 of Set 11 | fort stockton
# Processing Record 16 of Set 11 | krasnovishersk
# Processing Record 17 of Set 11 | tidjikja
# Processing Record 18 of Set 11 | namanga
# Processing Record 19 of Set 11 | pathalgaon
# Processing Record 20 of Set 11 | port hedland
# Processing Record 21 of Set 11 | waiuku
# Processing Record 22 of Set 11 | alzamay
# Processing Record 23 of Set 11 | tvoroyri
# Processing Record 24 of Set 11 | kiffa
# Processing Record 25 of Set 11 | paso de los toros
# Processing Record 26 of Set 11 | muravlenko
# Processing Record 27 of Set 11 | abraham's bay
# City not found. Skipping...
# Processing Record 28 of Set 11 | okhotsk
# Processing Record 29 of Set 11 | parnamirim
# Processing Record 30 of Set 11 | chuzhou
# Processing Record 31 of Set 11 | humahuaca
# Processing Record 32 of Set 11 | kabwe
# Processing Record 33 of Set 11 | kanniyakumari
# Processing Record 34 of Set 11 | monrovia
# Processing Record 35 of Set 11 | vershino-darasunskiy
# Processing Record 36 of Set 11 | lupane
# Processing Record 37 of Set 11 | ta`u
# Processing Record 38 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 39 of Set 11 | campbellsville
# Processing Record 40 of Set 11 | xinyu
# Processing Record 41 of Set 11 | wicklow
# Processing Record 42 of Set 11 | cable beach
# City not found. Skipping...
# Processing Record 43 of Set 11 | luau
# Processing Record 44 of Set 11 | nikolayevsk-on-amure
# Processing Record 45 of Set 11 | anibare
# City not found. Skipping...
# Processing Record 46 of Set 11 | al wajh
# Processing Record 47 of Set 11 | inhambane
# Processing Record 48 of Set 11 | loreto
# Processing Record 49 of Set 11 | richfield
# Processing Record 0 of Set 12 | la mira
# Processing Record 1 of Set 12 | khanbari
# Processing Record 2 of Set 12 | galesong
# Processing Record 3 of Set 12 | vilyuysk
# Processing Record 4 of Set 12 | colonia
# Processing Record 5 of Set 12 | parabel'
# Processing Record 6 of Set 12 | ephraim
# Processing Record 7 of Set 12 | isle of lewis
# City not found. Skipping...
# Processing Record 8 of Set 12 | flying fish cove
# Processing Record 9 of Set 12 | dzhalagash
# Processing Record 10 of Set 12 | shchyolkino
# Processing Record 11 of Set 12 | bamboo flat
# Processing Record 12 of Set 12 | san mariano
# Processing Record 13 of Set 12 | dingalan
# Processing Record 14 of Set 12 | novodvinsk
# Processing Record 15 of Set 12 | taltal
# Processing Record 16 of Set 12 | buka
# Processing Record 17 of Set 12 | soe
# Processing Record 18 of Set 12 | mumford
# Processing Record 19 of Set 12 | pechory
# Processing Record 20 of Set 12 | oblivskaya
# Processing Record 21 of Set 12 | dubovka
# Processing Record 22 of Set 12 | kyakhta
# Processing Record 23 of Set 12 | plastun
# Processing Record 24 of Set 12 | beyneu
# Processing Record 25 of Set 12 | yorkton
# Processing Record 26 of Set 12 | sonsorol village
# City not found. Skipping...
# Processing Record 27 of Set 12 | montrose
# Processing Record 28 of Set 12 | aroma
# Processing Record 29 of Set 12 | dodoma
# Processing Record 30 of Set 12 | qusmuryn
# Processing Record 31 of Set 12 | baglung
# Processing Record 32 of Set 12 | bao loc
# City not found. Skipping...
# Processing Record 33 of Set 12 | tank
# Processing Record 34 of Set 12 | camp verde
# Processing Record 35 of Set 12 | puducherry
# Processing Record 36 of Set 12 | hiawatha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# res = requests.get(city_url).json()
# res
# city_url

# %%
# res['dt']

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          562
# Lat           562
# Lng           562
# Max Temp      562
# Humidity      562
# Cloudiness    562
# Wind Speed    562
# Country       562
# Date          562
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        gweru -19.4500   29.8167     14.49        89         100        5.52
# 1       palmer  42.1584  -72.3287     15.84        83         100        3.09
# 2    adamstown -25.0660 -130.1015     21.83        55          29        6.78
# 3       bethel  41.3712  -73.4140     16.79        89         100        4.12
# 4  yellowknife  62.4560 -114.3525      3.29        56          20        6.17
#
#   Country        Date
# 0      ZW  1712890528
# 1      US  1712890253
# 2      PN  1712890240
# 3      US  1712890249
# 4      CA  1712890303

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              gweru -19.4500   29.8167     14.49        89         100
# 1             palmer  42.1584  -72.3287     15.84        83         100
# 2          adamstown -25.0660 -130.1015     21.83        55          29
# 3             bethel  41.3712  -73.4140     16.79        89         100
# 4        yellowknife  62.4560 -114.3525      3.29        56          20
#
#          Wind Speed Country        Date
# City_ID
# 0              5.52      ZW  1712890528
# 1              3.09      US  1712890253
# 2              6.78      PN  1712890240
# 3              4.12      US  1712890249
# 4              6.17      CA  1712890303

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Convert 'Date' column to ISO date format  (YYYY-MM-dd)
city_data_df
# city_data_df['Date'] = pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d')
city_data_df['Date'] = pd.to_datetime(city_data_df['Date']).dt.strftime('%Y-%m-%d')

city_data_df.head()
# Find the minimum and maximum dates
min_date = city_data_df['Date'].min()
max_date = city_data_df['Date'].max()

# Print the range of dates
# print("Date Range:", min_date, "to", max_date)
timeDate = max_date
# timeDate

# %%
# Scatter plot for latitude vs. temperature

# Filter the data for the specific date (timeDate)
specific_date_data = city_data_df[city_data_df['Date'] == timeDate]

plt.scatter(specific_date_data['Lat'], specific_date_data['Max Temp'], edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Max Temperature ({timeDate})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Observation: The scatter plot of Temperature (°C) vs. Latitude plot shown above illustrated temperature peaks at approximately 20-degrees latitude. The latitude values below that latitude show a possible positive linear relationship with temperature, and those above latitude 20 degrees suggest a negative linear relationship with temperature.

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Scatter plot for latitude vs. temperature

# Filter the data for the specific date 
specific_date_data = city_data_df[city_data_df['Date'] == timeDate]

plt.scatter(specific_date_data['Lat'], specific_date_data['Humidity'], edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Humidity ({timeDate})')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Observation: The Humidity vs. Latitude scatter plot above with data from all cities suggests a relatively spread-out distribution of data points. There seems to be no relationship between humidity and latitude but the humidity percentages seem to largely cluster above 50%.

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Scatter plot for latitude vs. cloudiness

# Filter the data for the specific date (2024-04-11)
specific_date_data = city_data_df[city_data_df['Date'] == timeDate]

plt.scatter(specific_date_data['Lat'], specific_date_data['Cloudiness'], edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Cloudiness ({timeDate})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Observation: The scatter plot on Cloudiness vs. Latitude above, is from data of all the cities. It seems to suggest no relationship between cloudiness and city latitude. Whereas some cloudiness values point to clustering 0, 20, 40, 75, 90, and 100, these values may be rounded or categorized from some of the sources, and thus may not represent continuous variables or measurements.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

# Filter the data for the specific date (2024-04-11)
specific_date_data = city_data_df[city_data_df['Date'] == timeDate]

# Scatter plot for latitude vs. wind speed
plt.scatter(specific_date_data['Lat'], specific_date_data['Wind Speed'], edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Wind Speed ({timeDate})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# #### Observation: The scatter plot on City Wind speed vs. Latitude, seems not to show any relationship between wind speed and latitude but clustering. Most of the wind speed values are below about 25 mph.

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression_plot(x_values, y_values, xlabel, ylabel, title, file_name):
   
    # Function to create a linear regression plot.

    # Parameters:
    # x_values: The values for the x-axis.
    # y_values: The values for the y-axis.
    # xlabel: The label for the x-axis.
    # ylabel: The label for the y-axis.
    # title: The title of the plot.
    # file_name: The file name for saving the plot (optional).

    # Returns:
    # None
   
    # Perform linear regression
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

    # Calculate the regression line
    regress_values = x_values * slope + intercept

    # Create scatter plot
    plt.scatter(x_values, y_values, edgecolors='black', alpha=0.75)

    # Plot regression line
    plt.plot(x_values, regress_values, color='red')

    # Annotate the linear regression equation and correlation coefficient on the plot
    line_eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}\nR² = {round(rvalue**2, 2)}'
    plt.annotate(line_eq, (x_values.min(), y_values.max()), fontsize=12, 
                 color='red', xytext=(20, -320), textcoords='offset points')



    # Set plot labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)

    # Save the figure if has file_name
    if file_name:
        plt.savefig(file_name)

    # Show plot
    plt.show()

# Test
# linear_regression_plot(city_data_df['Lat'], city_data_df['Max Temp'], 'Latitude', 'Max Temperature (°C)', 
#                        'City Latitude vs. Max Temperature Linear Regression', 'output_data/lat_vs_max_temp_regression.png')

# %%
# Create DataFrame for Northern Hemisphere data
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             palmer  42.1584  -72.3287     15.84        83         100
# 3             bethel  41.3712  -73.4140     16.79        89         100
# 4        yellowknife  62.4560 -114.3525      3.29        56          20
# 8            hanover  52.3705    9.7332     14.48        92         100
# 11           sandwip  22.4678   91.4561     29.02        61          96
#
#          Wind Speed Country        Date
# City_ID
# 1              3.09      US  1970-01-01
# 3              4.12      US  1970-01-01
# 4              6.17      CA  1970-01-01
# 8              2.06      DE  1970-01-01
# 11             2.13      BD  1970-01-01

# %%
# Create DataFrame for Southern Hemisphere data
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               gweru -19.4500   29.8167     14.49        89         100
# 2           adamstown -25.0660 -130.1015     21.83        55          29
# 5        punta arenas -53.1500  -70.9167      8.06        76          40
# 6             kencong  -8.2833  113.3667     29.13        72          33
# 7           grytviken -54.2811  -36.5092     -1.63        68           7
#
#          Wind Speed Country        Date
# City_ID
# 0              5.52      ZW  1970-01-01
# 2              6.78      PN  1970-01-01
# 5             10.29      CL  1970-01-01
# 6              2.18      ID  1970-01-01
# 7              4.46      GS  1970-01-01

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Linear regression on Northern Hemisphere for latitude vs. maximum temperature
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Latitude', 'Max Temperature (°C)', 
                       'Northern Hemisphere - City Latitude vs. Max Temperature Linear Regression', 
                       'output_data/northern_hemi_lat_vs_max_temp_regression.png')

# %%
# Linear regression on Southern Hemisphere

# Linear regression on Southern Hemisphere for latitude vs. maximum temperature
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Latitude', 'Max Temperature (°C)', 
                       'Southern Hemisphere - City Latitude vs. Max Temperature Linear Regression', 
                       'output_data/southern_hemi_lat_vs_max_temp_regression.png')

# %% [markdown]
# #### Observation: There is a strong negative correlation (R^2 = 79%) between Max Temperature and Latitude in the Northern hemisphere. The higher the latitude the cooler it becomes. Conversely, in the Southern hemisphere, there is a moderately positive correlation (R^2 = 55%), here, an increase in latitude is associated with a moderate increase in temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere for latitude vs. humidity
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 
                       'Humidity (%)', 'Northern Hemisphere - City Latitude vs. Humidity Linear Regression', 
                       'output_data/northern_hemi_lat_vs_humidity_regression.png')

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere for latitude vs. humidity
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 
                       'Humidity (%)', 'Southern Hemisphere - City Latitude vs. Humidity Linear Regression', 
                       'output_data/southern_hemi_lat_vs_humidity_regression.png')

# %% [markdown]
# #### Observation: The correlation coefficent between latitude and humidity in the Northern hemisphere is less than 10% suggesting no relationship between the two, while in the Southern hemisphere, there is a very weak positive correlation (r=12%) between latitude and humidity. An increase in humidity is not really associated with an increase in latitude in the cities.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Linear regression on Northern Hemisphere for latitude vs. cloudiness
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Latitude', 
                       'Cloudiness (%)', 'Northern Hemisphere - City Latitude vs. Cloudiness Linear Regression', 
                       'output_data/northern_hemi_lat_vs_cloudiness_regression.png')

# %%
# Southern Hemisphere

# Linear regression on Northern Hemisphere for latitude vs. cloudiness
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Latitude', 
                       'Cloudiness (%)', 'Southern Hemisphere - City Latitude vs. Cloudiness Linear Regression', 
                       'output_data/southern_hemi_lat_vs_cloudiness_regression.png')

# %% [markdown]
# #### Observation: There is no relationship between the latitude of a city in either the Northern or Southern Hemisphere and Cloudiness considering their very week correlation coefficients, r= 4% and r = 7% respectively.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Nothern Hemisphere

# Linear regression on Northern Hemisphere for latitude vs. wind speed
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed (m/s)', 
                       'Northern Hemisphere - City Latitude vs. Wind Speed Linear Regression', 
                       'output_data/northern_hemi_lat_vs_wind_speed_regression.png')

# %%
# Southern Hemisphere

# Linear regression on Northern Hemisphere for latitude vs. wind speed
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed (m/s)', 
                       'Southern Hemisphere - City Latitude vs. Wind Speed Linear Regression', 
                       'output_data/southern_hemi_lat_vs_wind_speed_regression.png')

# %% [markdown]
# #### Observation: There is no relationship between the change in latitude in a city in the Northern Hemisphere and wind speed looking at r = 6%. A very weak negative relationship may exist between latitude and wind speed for cities in the Southern Hemisphere, r=11%.
