# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !conda install -c pyviz hvplot geoviews -y
# !pip install census
# !pip install citipy
# Out:
# Channels:
#  - pyviz
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Requirement already satisfied: census in c:\users\maero\appdata\roaming\python\python310\site-packages (0.8.21)
# Requirement already satisfied: requests>=1.1.0 in c:\programdata\anaconda3\envs\dev\lib\site-packages (from census) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\dev\lib\site-packages (from requests>=1.1.0->census) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\dev\lib\site-packages (from requests>=1.1.0->census) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\dev\lib\site-packages (from requests>=1.1.0->census) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\dev\lib\site-packages (from requests>=1.1.0->census) (2024.2.2)
# Requirement already satisfied: citipy in c:\programdata\anaconda3\envs\dev\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\programdata\anaconda3\envs\dev\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 608

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
# url = # YOUR CODE HERE
url = "http://api.openweathermap.org/data/2.5/weather?"



# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    # city_url = # YOUR CODE HERE
    city_url = url  + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        # city_weather = # YOUR CODE HERE
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        # city_lat = # YOUR CODE HERE
        city_lat = city_weather['coord']['lat']

        city_lng = city_weather['coord']['lon']

        # convert Kelvin into Celsius is C = K - 273.15
        city_max_temp = city_weather['main']['temp_max'] - 273.15
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bazarnyye mataki
# Processing Record 2 of Set 1 | edinburgh of the seven seas
# Processing Record 3 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | port saint john's
# Processing Record 6 of Set 1 | colesberg
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | ust-nera
# Processing Record 11 of Set 1 | yuzhno-kurilsk
# Processing Record 12 of Set 1 | waitangi
# Processing Record 13 of Set 1 | barkly west
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | aasiaat
# Processing Record 16 of Set 1 | fortuna
# Processing Record 17 of Set 1 | tlahualilo de zaragoza
# Processing Record 18 of Set 1 | blackmans bay
# Processing Record 19 of Set 1 | isafjordur
# Processing Record 20 of Set 1 | hamilton
# Processing Record 21 of Set 1 | quepos
# Processing Record 22 of Set 1 | nizhniy kuranakh
# Processing Record 23 of Set 1 | hohhot
# Processing Record 24 of Set 1 | bedesa
# Processing Record 25 of Set 1 | nobres
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | umea
# Processing Record 28 of Set 1 | alegrete
# Processing Record 29 of Set 1 | grytviken
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | taza
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | azul
# Processing Record 34 of Set 1 | whitehorse
# Processing Record 35 of Set 1 | afaahiti
# Processing Record 36 of Set 1 | vorkuta
# Processing Record 37 of Set 1 | kone
# Processing Record 38 of Set 1 | aberdeen
# Processing Record 39 of Set 1 | saipan
# Processing Record 40 of Set 1 | antsiranana
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | bataipora
# Processing Record 43 of Set 1 | kimbe
# Processing Record 44 of Set 1 | carbonear
# Processing Record 45 of Set 1 | wailua homesteads
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 48 of Set 1 | kualakapuas
# Processing Record 49 of Set 1 | pangody
# Processing Record 50 of Set 1 | puerto natales
# Processing Record 0 of Set 2 | grand falls-windsor
# Processing Record 1 of Set 2 | mil'kovo
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | olonkinbyen
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | vila franca do campo
# Processing Record 6 of Set 2 | bengkulu
# Processing Record 7 of Set 2 | ancud
# Processing Record 8 of Set 2 | sao jose de ribamar
# Processing Record 9 of Set 2 | port-vila
# Processing Record 10 of Set 2 | griffith
# Processing Record 11 of Set 2 | frolovo
# Processing Record 12 of Set 2 | udachny
# Processing Record 13 of Set 2 | susuman
# Processing Record 14 of Set 2 | adamstown
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | puerto baquerizo moreno
# Processing Record 17 of Set 2 | wynyard
# Processing Record 18 of Set 2 | chengdu
# Processing Record 19 of Set 2 | nova sintra
# Processing Record 20 of Set 2 | mili
# Processing Record 21 of Set 2 | kingston
# Processing Record 22 of Set 2 | zlatni pyasatsi
# Processing Record 23 of Set 2 | vetluga
# Processing Record 24 of Set 2 | sumbe
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | klyuchi
# Processing Record 27 of Set 2 | remire-montjoly
# Processing Record 28 of Set 2 | margaret river
# Processing Record 29 of Set 2 | happy valley-goose bay
# Processing Record 30 of Set 2 | akureyri
# Processing Record 31 of Set 2 | kapuskasing
# Processing Record 32 of Set 2 | wotje
# Processing Record 33 of Set 2 | rio tuba
# Processing Record 34 of Set 2 | sao joao da barra
# Processing Record 35 of Set 2 | utrik
# Processing Record 36 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 37 of Set 2 | nova londrina
# Processing Record 38 of Set 2 | mukah
# City not found. Skipping...
# Processing Record 39 of Set 2 | thinadhoo
# Processing Record 40 of Set 2 | talnakh
# Processing Record 41 of Set 2 | plastun
# Processing Record 42 of Set 2 | machico
# Processing Record 43 of Set 2 | midvagur
# Processing Record 44 of Set 2 | seaside
# Processing Record 45 of Set 2 | tarfaya
# Processing Record 46 of Set 2 | tazovsky
# Processing Record 47 of Set 2 | thai binh
# Processing Record 48 of Set 2 | tangshan
# Processing Record 49 of Set 2 | tolanaro
# Processing Record 0 of Set 3 | san antonio de pale
# Processing Record 1 of Set 3 | saint-pierre
# Processing Record 2 of Set 3 | atamyrat
# Processing Record 3 of Set 3 | college
# Processing Record 4 of Set 3 | tazacorte
# Processing Record 5 of Set 3 | qaqortoq
# Processing Record 6 of Set 3 | mount pearl
# Processing Record 7 of Set 3 | callao
# Processing Record 8 of Set 3 | geraldton
# Processing Record 9 of Set 3 | ushuaia
# Processing Record 10 of Set 3 | iskateley
# Processing Record 11 of Set 3 | vuokatti
# Processing Record 12 of Set 3 | stanley
# Processing Record 13 of Set 3 | harstad
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | waingapu
# Processing Record 16 of Set 3 | kraaifontein
# Processing Record 17 of Set 3 | elliot
# Processing Record 18 of Set 3 | ko lanta
# Processing Record 19 of Set 3 | cova figueira
# Processing Record 20 of Set 3 | nar'yan-mar
# Processing Record 21 of Set 3 | kudahuvadhoo
# Processing Record 22 of Set 3 | pimenta bueno
# Processing Record 23 of Set 3 | kargopol'
# Processing Record 24 of Set 3 | west island
# Processing Record 25 of Set 3 | kalmunai
# Processing Record 26 of Set 3 | dunedin
# Processing Record 27 of Set 3 | bukene
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | natitingou
# Processing Record 30 of Set 3 | papatowai
# Processing Record 31 of Set 3 | enewetak
# Processing Record 32 of Set 3 | orsta
# Processing Record 33 of Set 3 | san andros
# City not found. Skipping...
# Processing Record 34 of Set 3 | pointe-noire
# Processing Record 35 of Set 3 | bat yam
# Processing Record 36 of Set 3 | turbat
# Processing Record 37 of Set 3 | ouellah
# City not found. Skipping...
# Processing Record 38 of Set 3 | kavaratti
# Processing Record 39 of Set 3 | gariadhar
# Processing Record 40 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 41 of Set 3 | katsuura
# Processing Record 42 of Set 3 | tarko-sale
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | walvis bay
# Processing Record 45 of Set 3 | nueve de julio
# Processing Record 46 of Set 3 | smara
# Processing Record 47 of Set 3 | santa marta
# Processing Record 48 of Set 3 | izhmorskiy
# Processing Record 49 of Set 3 | pandan
# Processing Record 0 of Set 4 | as sulayyil
# Processing Record 1 of Set 4 | fort bragg
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | saint-denis
# Processing Record 4 of Set 4 | paita
# Processing Record 5 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 4 | oum hadjer
# Processing Record 7 of Set 4 | mahina
# Processing Record 8 of Set 4 | peace river
# Processing Record 9 of Set 4 | constantia
# Processing Record 10 of Set 4 | kawthoung
# City not found. Skipping...
# Processing Record 11 of Set 4 | anadyr
# Processing Record 12 of Set 4 | invercargill
# Processing Record 13 of Set 4 | boma
# Processing Record 14 of Set 4 | hilo
# Processing Record 15 of Set 4 | burang
# Processing Record 16 of Set 4 | janeng
# Processing Record 17 of Set 4 | bereeda
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | jamestown
# Processing Record 20 of Set 4 | st. john's
# Processing Record 21 of Set 4 | hawaiian paradise park
# Processing Record 22 of Set 4 | anna regina
# Processing Record 23 of Set 4 | kuusamo
# Processing Record 24 of Set 4 | mount isa
# Processing Record 25 of Set 4 | bojnurd
# Processing Record 26 of Set 4 | ijuw
# City not found. Skipping...
# Processing Record 27 of Set 4 | hincesti
# Processing Record 28 of Set 4 | faqus
# Processing Record 29 of Set 4 | dapa
# Processing Record 30 of Set 4 | haiku-pauwela
# Processing Record 31 of Set 4 | etinan
# Processing Record 32 of Set 4 | claveria
# Processing Record 33 of Set 4 | bhamo
# Processing Record 34 of Set 4 | azna
# Processing Record 35 of Set 4 | bilibino
# Processing Record 36 of Set 4 | cartagena del chaira
# Processing Record 37 of Set 4 | las vegas
# Processing Record 38 of Set 4 | al ghayzah
# Processing Record 39 of Set 4 | crane
# Processing Record 40 of Set 4 | villa gesell
# Processing Record 41 of Set 4 | porto novo
# Processing Record 42 of Set 4 | cerrik
# Processing Record 43 of Set 4 | gueoul
# City not found. Skipping...
# Processing Record 44 of Set 4 | luderitz
# Processing Record 45 of Set 4 | mammoth lakes
# Processing Record 46 of Set 4 | jurmala
# Processing Record 47 of Set 4 | carnarvon
# Processing Record 48 of Set 4 | tobruk
# Processing Record 49 of Set 4 | piti village
# Processing Record 0 of Set 5 | mogocha
# Processing Record 1 of Set 5 | korla
# Processing Record 2 of Set 5 | bishunpur urf maharajganj
# Processing Record 3 of Set 5 | santa cruz
# Processing Record 4 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 5 of Set 5 | port mathurin
# Processing Record 6 of Set 5 | port alfred
# Processing Record 7 of Set 5 | lihue
# Processing Record 8 of Set 5 | kailua-kona
# Processing Record 9 of Set 5 | colonia
# Processing Record 10 of Set 5 | ghanzi
# Processing Record 11 of Set 5 | nabire
# Processing Record 12 of Set 5 | chonchi
# Processing Record 13 of Set 5 | argo
# Processing Record 14 of Set 5 | shihezi
# Processing Record 15 of Set 5 | lompoc
# Processing Record 16 of Set 5 | toliara
# Processing Record 17 of Set 5 | cidade velha
# Processing Record 18 of Set 5 | laojunmiao
# Processing Record 19 of Set 5 | fale old settlement
# Processing Record 20 of Set 5 | puerto deseado
# Processing Record 21 of Set 5 | annaba
# Processing Record 22 of Set 5 | kismayo
# Processing Record 23 of Set 5 | road town
# Processing Record 24 of Set 5 | kani keli
# Processing Record 25 of Set 5 | pontianak
# Processing Record 26 of Set 5 | sevastopol
# Processing Record 27 of Set 5 | rongelap
# Processing Record 28 of Set 5 | nyala
# Processing Record 29 of Set 5 | vorgashor
# Processing Record 30 of Set 5 | vadso
# Processing Record 31 of Set 5 | askoy
# Processing Record 32 of Set 5 | kirakira
# Processing Record 33 of Set 5 | angaur state
# Processing Record 34 of Set 5 | christchurch
# Processing Record 35 of Set 5 | neiafu
# Processing Record 36 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 37 of Set 5 | lagunas
# Processing Record 38 of Set 5 | chegdomyn
# Processing Record 39 of Set 5 | dakhla
# Processing Record 40 of Set 5 | daru
# Processing Record 41 of Set 5 | sharm el-sheikh
# Processing Record 42 of Set 5 | lindsay
# Processing Record 43 of Set 5 | putina
# Processing Record 44 of Set 5 | isangel
# Processing Record 45 of Set 5 | togur
# Processing Record 46 of Set 5 | tralee
# Processing Record 47 of Set 5 | tanjung selor
# City not found. Skipping...
# Processing Record 48 of Set 5 | kroya
# Processing Record 49 of Set 5 | lingdong
# Processing Record 0 of Set 6 | baracoa
# Processing Record 1 of Set 6 | princeville
# Processing Record 2 of Set 6 | taulaga
# Processing Record 3 of Set 6 | murashi
# Processing Record 4 of Set 6 | pudozh
# Processing Record 5 of Set 6 | mlowo
# Processing Record 6 of Set 6 | petukhovo
# Processing Record 7 of Set 6 | berdigestyakh
# Processing Record 8 of Set 6 | tanabi
# Processing Record 9 of Set 6 | tafuna
# Processing Record 10 of Set 6 | siwa oasis
# Processing Record 11 of Set 6 | nemuro
# Processing Record 12 of Set 6 | sarkand
# Processing Record 13 of Set 6 | yanam
# Processing Record 14 of Set 6 | grants pass
# Processing Record 15 of Set 6 | senhor do bonfim
# Processing Record 16 of Set 6 | preobrazheniye
# Processing Record 17 of Set 6 | california
# Processing Record 18 of Set 6 | okeechobee
# Processing Record 19 of Set 6 | mpulungu
# Processing Record 20 of Set 6 | 'ibri
# City not found. Skipping...
# Processing Record 21 of Set 6 | gadzhiyevo
# Processing Record 22 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 23 of Set 6 | rio grande
# Processing Record 24 of Set 6 | inhuma
# Processing Record 25 of Set 6 | malvik
# Processing Record 26 of Set 6 | newman
# Processing Record 27 of Set 6 | chu
# Processing Record 28 of Set 6 | tura
# Processing Record 29 of Set 6 | contai
# Processing Record 30 of Set 6 | kapa'a
# Processing Record 31 of Set 6 | sharlyk
# Processing Record 32 of Set 6 | gazli
# Processing Record 33 of Set 6 | nioki
# Processing Record 34 of Set 6 | mana
# Processing Record 35 of Set 6 | lauro de freitas
# Processing Record 36 of Set 6 | kayes
# Processing Record 37 of Set 6 | grand gaube
# Processing Record 38 of Set 6 | kourou
# Processing Record 39 of Set 6 | el calafate
# Processing Record 40 of Set 6 | badger
# Processing Record 41 of Set 6 | tsiombe
# Processing Record 42 of Set 6 | aykhal
# Processing Record 43 of Set 6 | alesund
# Processing Record 44 of Set 6 | ghat
# Processing Record 45 of Set 6 | vikhorevka
# Processing Record 46 of Set 6 | marka
# Processing Record 47 of Set 6 | san gabriel
# Processing Record 48 of Set 6 | ayaguz
# City not found. Skipping...
# Processing Record 49 of Set 6 | itoman
# Processing Record 0 of Set 7 | el palmar
# Processing Record 1 of Set 7 | uturoa
# Processing Record 2 of Set 7 | pangkalpinang
# Processing Record 3 of Set 7 | kunduz
# Processing Record 4 of Set 7 | korsholm
# Processing Record 5 of Set 7 | bel ombre
# Processing Record 6 of Set 7 | cairns city
# City not found. Skipping...
# Processing Record 7 of Set 7 | as samawah
# Processing Record 8 of Set 7 | dar naim
# City not found. Skipping...
# Processing Record 9 of Set 7 | myitkyina
# Processing Record 10 of Set 7 | ketchikan
# Processing Record 11 of Set 7 | lata
# Processing Record 12 of Set 7 | labytnangi
# Processing Record 13 of Set 7 | acarau
# Processing Record 14 of Set 7 | tonghua
# Processing Record 15 of Set 7 | shushtar
# Processing Record 16 of Set 7 | lundazi
# Processing Record 17 of Set 7 | zavodoukovsk
# Processing Record 18 of Set 7 | mong cai
# City not found. Skipping...
# Processing Record 19 of Set 7 | qamdo
# Processing Record 20 of Set 7 | hirara
# Processing Record 21 of Set 7 | maumere
# Processing Record 22 of Set 7 | brisas de zicatela
# Processing Record 23 of Set 7 | chinchilla
# Processing Record 24 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 25 of Set 7 | valley east
# City not found. Skipping...
# Processing Record 26 of Set 7 | morehead city
# Processing Record 27 of Set 7 | pohang
# Processing Record 28 of Set 7 | prince rupert
# Processing Record 29 of Set 7 | timbuktu
# Processing Record 30 of Set 7 | bikenibeu village
# Processing Record 31 of Set 7 | nurota
# Processing Record 32 of Set 7 | bodo
# Processing Record 33 of Set 7 | sao gabriel da cachoeira
# Processing Record 34 of Set 7 | nishinoomote
# Processing Record 35 of Set 7 | selfoss
# Processing Record 36 of Set 7 | cidreira
# Processing Record 37 of Set 7 | inirida
# Processing Record 38 of Set 7 | hermansverk
# Processing Record 39 of Set 7 | yung shue wan
# Processing Record 40 of Set 7 | dwarka
# Processing Record 41 of Set 7 | sisimiut
# Processing Record 42 of Set 7 | calama
# Processing Record 43 of Set 7 | yelizovo
# Processing Record 44 of Set 7 | lorengau
# Processing Record 45 of Set 7 | alofi
# Processing Record 46 of Set 7 | nouadhibou
# Processing Record 47 of Set 7 | guatire
# Processing Record 48 of Set 7 | manokwari
# Processing Record 49 of Set 7 | klerksdorp
# Processing Record 0 of Set 8 | karlskrona
# Processing Record 1 of Set 8 | norilsk
# Processing Record 2 of Set 8 | cabedelo
# Processing Record 3 of Set 8 | cabo san lucas
# Processing Record 4 of Set 8 | kuraymah
# Processing Record 5 of Set 8 | joshimath
# Processing Record 6 of Set 8 | pathein
# Processing Record 7 of Set 8 | gebeit
# Processing Record 8 of Set 8 | troitskiy
# Processing Record 9 of Set 8 | camocim
# Processing Record 10 of Set 8 | sukhobezvodnoye
# Processing Record 11 of Set 8 | inhambane
# Processing Record 12 of Set 8 | alagir
# Processing Record 13 of Set 8 | suva
# Processing Record 14 of Set 8 | flying fish cove
# Processing Record 15 of Set 8 | labuan lombok
# City not found. Skipping...
# Processing Record 16 of Set 8 | dalbandin
# Processing Record 17 of Set 8 | ataq
# Processing Record 18 of Set 8 | al jawf
# Processing Record 19 of Set 8 | nikolayevsk-on-amure
# Processing Record 20 of Set 8 | bedele
# Processing Record 21 of Set 8 | sovetskaya
# Processing Record 22 of Set 8 | kolonia
# Processing Record 23 of Set 8 | maine soroa
# Processing Record 24 of Set 8 | sinop
# Processing Record 25 of Set 8 | kolpashevo
# Processing Record 26 of Set 8 | mossendjo
# Processing Record 27 of Set 8 | vilyuchinsk
# Processing Record 28 of Set 8 | kitami
# Processing Record 29 of Set 8 | skutskar
# City not found. Skipping...
# Processing Record 30 of Set 8 | marrakesh
# Processing Record 31 of Set 8 | ambovombe
# Processing Record 32 of Set 8 | thompson
# Processing Record 33 of Set 8 | maracaibo
# Processing Record 34 of Set 8 | jiuquan
# Processing Record 35 of Set 8 | tamiahua
# Processing Record 36 of Set 8 | novoishimskiy
# Processing Record 37 of Set 8 | biloxi
# Processing Record 38 of Set 8 | pisco
# Processing Record 39 of Set 8 | celestun
# Processing Record 40 of Set 8 | kayangel
# Processing Record 41 of Set 8 | mugia
# Processing Record 42 of Set 8 | sungjibaegam
# Processing Record 43 of Set 8 | quellon
# Processing Record 44 of Set 8 | nagahama
# Processing Record 45 of Set 8 | fort mcmurray
# Processing Record 46 of Set 8 | pirenopolis
# Processing Record 47 of Set 8 | mahabe
# City not found. Skipping...
# Processing Record 48 of Set 8 | sitka
# Processing Record 49 of Set 8 | arraial do cabo
# Processing Record 0 of Set 9 | hadibu
# Processing Record 1 of Set 9 | holualoa
# Processing Record 2 of Set 9 | krasnokamensk
# Processing Record 3 of Set 9 | ghadamis
# Processing Record 4 of Set 9 | minas de marcona
# Processing Record 5 of Set 9 | paka
# Processing Record 6 of Set 9 | riberalta
# Processing Record 7 of Set 9 | coahuayana de hidalgo
# Processing Record 8 of Set 9 | lionel town
# Processing Record 9 of Set 9 | tomohon
# Processing Record 10 of Set 9 | nadym
# Processing Record 11 of Set 9 | scarborough
# Processing Record 12 of Set 9 | huarmey
# Processing Record 13 of Set 9 | dudinka
# Processing Record 14 of Set 9 | port lincoln
# Processing Record 15 of Set 9 | weno
# Processing Record 16 of Set 9 | dryden
# Processing Record 17 of Set 9 | ballina
# Processing Record 18 of Set 9 | palmer
# Processing Record 19 of Set 9 | punta arenas
# Processing Record 20 of Set 9 | ust'-barguzin
# Processing Record 21 of Set 9 | yandev
# Processing Record 22 of Set 9 | toccoa
# Processing Record 23 of Set 9 | lagos
# Processing Record 24 of Set 9 | benguela
# Processing Record 25 of Set 9 | yulinshi
# Processing Record 26 of Set 9 | katsuren-haebaru
# Processing Record 27 of Set 9 | al hasakah
# Processing Record 28 of Set 9 | sile
# Processing Record 29 of Set 9 | hotan
# Processing Record 30 of Set 9 | amahai
# Processing Record 31 of Set 9 | belmonte
# Processing Record 32 of Set 9 | cruzeiro do sul
# Processing Record 33 of Set 9 | barra de santo antonio
# Processing Record 34 of Set 9 | barcelona
# Processing Record 35 of Set 9 | sao jose da coroa grande
# Processing Record 36 of Set 9 | fall river
# Processing Record 37 of Set 9 | hasaki
# Processing Record 38 of Set 9 | jianshui
# Processing Record 39 of Set 9 | island harbour
# Processing Record 40 of Set 9 | bodaybo
# Processing Record 41 of Set 9 | new norfolk
# Processing Record 42 of Set 9 | san patricio
# Processing Record 43 of Set 9 | rosetta
# Processing Record 44 of Set 9 | ola
# Processing Record 45 of Set 9 | nykobing sjaelland
# Processing Record 46 of Set 9 | maintirano
# Processing Record 47 of Set 9 | kill devil hills
# Processing Record 48 of Set 9 | khemisset
# Processing Record 49 of Set 9 | medina
# Processing Record 0 of Set 10 | terekeka
# City not found. Skipping...
# Processing Record 1 of Set 10 | atafu village
# Processing Record 2 of Set 10 | andkhoy
# Processing Record 3 of Set 10 | namibe
# Processing Record 4 of Set 10 | reggane
# Processing Record 5 of Set 10 | beira
# Processing Record 6 of Set 10 | lembar
# City not found. Skipping...
# Processing Record 7 of Set 10 | port douglas
# Processing Record 8 of Set 10 | beau vallon
# Processing Record 9 of Set 10 | phan thong
# Processing Record 10 of Set 10 | bima
# Processing Record 11 of Set 10 | praia da vitoria
# Processing Record 12 of Set 10 | karachayevsk
# Processing Record 13 of Set 10 | arteche
# Processing Record 14 of Set 10 | clorinda
# Processing Record 15 of Set 10 | paracuru
# Processing Record 16 of Set 10 | bogale
# Processing Record 17 of Set 10 | maragogi
# Processing Record 18 of Set 10 | fort st. john
# Processing Record 19 of Set 10 | manadhoo
# Processing Record 20 of Set 10 | mantua
# Processing Record 21 of Set 10 | talara
# Processing Record 22 of Set 10 | dobrotesti
# Processing Record 23 of Set 10 | san juan
# Processing Record 24 of Set 10 | pemangkat
# Processing Record 25 of Set 10 | kadom
# Processing Record 26 of Set 10 | fedorovka
# Processing Record 27 of Set 10 | campbellton
# Processing Record 28 of Set 10 | south hedland
# Processing Record 29 of Set 10 | east london
# Processing Record 30 of Set 10 | palafrugell
# Processing Record 31 of Set 10 | kuhmo
# Processing Record 32 of Set 10 | farafangana
# Processing Record 33 of Set 10 | arkhangel'sk
# Processing Record 34 of Set 10 | keflavik
# Processing Record 35 of Set 10 | faya-largeau
# Processing Record 36 of Set 10 | laguna de perlas
# Processing Record 37 of Set 10 | xuchang
# Processing Record 38 of Set 10 | rio grande city
# Processing Record 39 of Set 10 | hamirpur
# Processing Record 40 of Set 10 | nantucket
# Processing Record 41 of Set 10 | kasane
# Processing Record 42 of Set 10 | sambava
# Processing Record 43 of Set 10 | severnoye
# Processing Record 44 of Set 10 | usinsk
# Processing Record 45 of Set 10 | nuku'alofa
# Processing Record 46 of Set 10 | grand-lahou
# Processing Record 47 of Set 10 | am djarass
# City not found. Skipping...
# Processing Record 48 of Set 10 | axim
# Processing Record 49 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 0 of Set 11 | zemio
# Processing Record 1 of Set 11 | taibet
# City not found. Skipping...
# Processing Record 2 of Set 11 | chake chake
# Processing Record 3 of Set 11 | padang
# Processing Record 4 of Set 11 | melilla
# Processing Record 5 of Set 11 | morant bay
# Processing Record 6 of Set 11 | jean-rabel
# Processing Record 7 of Set 11 | naliya
# Processing Record 8 of Set 11 | alice springs
# Processing Record 9 of Set 11 | muscat
# Processing Record 10 of Set 11 | puerto asis
# Processing Record 11 of Set 11 | codrington
# Processing Record 12 of Set 11 | lockwood
# Processing Record 13 of Set 11 | la passe
# Processing Record 14 of Set 11 | zahedan
# Processing Record 15 of Set 11 | polyarnyy
# Processing Record 16 of Set 11 | chingirlau
# Processing Record 17 of Set 11 | odda
# Processing Record 18 of Set 11 | mo i rana
# Processing Record 19 of Set 11 | moussoro
# Processing Record 20 of Set 11 | monrovia
# Processing Record 21 of Set 11 | khovd
# Processing Record 22 of Set 11 | corinto
# Processing Record 23 of Set 11 | belomorsk
# Processing Record 24 of Set 11 | palikir - national government center
# Processing Record 25 of Set 11 | mournies
# Processing Record 26 of Set 11 | palmas
# Processing Record 27 of Set 11 | peniche
# Processing Record 28 of Set 11 | ocotal
# Processing Record 29 of Set 11 | kembe
# Processing Record 30 of Set 11 | port augusta
# Processing Record 31 of Set 11 | gueltat zemmour
# City not found. Skipping...
# Processing Record 32 of Set 11 | gamboma
# Processing Record 33 of Set 11 | lethem
# Processing Record 34 of Set 11 | sohag
# Processing Record 35 of Set 11 | lubao
# Processing Record 36 of Set 11 | bubaque
# Processing Record 37 of Set 11 | tocopilla
# Processing Record 38 of Set 11 | funafuti
# Processing Record 39 of Set 11 | hammerfest
# Processing Record 40 of Set 11 | broome
# Processing Record 41 of Set 11 | salalah
# Processing Record 42 of Set 11 | smirnykh
# Processing Record 43 of Set 11 | dolores
# Processing Record 44 of Set 11 | zeribet el oued
# Processing Record 45 of Set 11 | malango
# Processing Record 46 of Set 11 | bandar abbas
# Processing Record 47 of Set 11 | smithers
# Processing Record 48 of Set 11 | gwio kura
# Processing Record 49 of Set 11 | bijawar
# Processing Record 0 of Set 12 | douglas
# Processing Record 1 of Set 12 | buka
# Processing Record 2 of Set 12 | san luis de la loma
# Processing Record 3 of Set 12 | quartu sant'elena
# Processing Record 4 of Set 12 | klaksvik
# Processing Record 5 of Set 12 | las heras
# Processing Record 6 of Set 12 | prado
# Processing Record 7 of Set 12 | barra
# Processing Record 8 of Set 12 | heiden
# Processing Record 9 of Set 12 | roma
# Processing Record 10 of Set 12 | alta
# Processing Record 11 of Set 12 | ordos
# City not found. Skipping...
# Processing Record 12 of Set 12 | galappo
# Processing Record 13 of Set 12 | afif
# Processing Record 14 of Set 12 | ta`u
# Processing Record 15 of Set 12 | anabar
# City not found. Skipping...
# Processing Record 16 of Set 12 | karratha
# Processing Record 17 of Set 12 | west end village
# City not found. Skipping...
# Processing Record 18 of Set 12 | mont-joli
# Processing Record 19 of Set 12 | inda silase
# Processing Record 20 of Set 12 | caleta de carquin
# Processing Record 21 of Set 12 | acapulco de juarez
# Processing Record 22 of Set 12 | vingt cinq
# City not found. Skipping...
# Processing Record 23 of Set 12 | newport
# Processing Record 24 of Set 12 | ebon
# Processing Record 25 of Set 12 | sergeyevka
# Processing Record 26 of Set 12 | villa ojo de agua
# Processing Record 27 of Set 12 | penzance
# Processing Record 28 of Set 12 | dawei
# Processing Record 29 of Set 12 | senanga
# Processing Record 30 of Set 12 | oyem
# Processing Record 31 of Set 12 | shakawe
# Processing Record 32 of Set 12 | nova vicosa
# Processing Record 33 of Set 12 | nagqu
# Processing Record 34 of Set 12 | nema
# Processing Record 35 of Set 12 | rikaze
# Processing Record 36 of Set 12 | westport
# Processing Record 37 of Set 12 | shimoda
# Processing Record 38 of Set 12 | posto fiscal rolim de moura
# Processing Record 39 of Set 12 | likiep
# Processing Record 40 of Set 12 | lautoka
# Processing Record 41 of Set 12 | pauini
# Processing Record 42 of Set 12 | melekeok village
# Processing Record 43 of Set 12 | champerico
# Processing Record 44 of Set 12 | deir ez-zor
# Processing Record 45 of Set 12 | severo-yeniseyskiy
# Processing Record 46 of Set 12 | nanping
# Processing Record 47 of Set 12 | lazaro cardenas
# Processing Record 48 of Set 12 | jaru
# Processing Record 49 of Set 12 | impfondo
# Processing Record 0 of Set 13 | chernyshevskiy
# Processing Record 1 of Set 13 | ciudad camilo cienfuegos
# City not found. Skipping...
# Processing Record 2 of Set 13 | saldanha
# Processing Record 3 of Set 13 | sabzevar
# Processing Record 4 of Set 13 | chengyang
# Processing Record 5 of Set 13 | kununurra
# Processing Record 6 of Set 13 | tromso
# Processing Record 7 of Set 13 | las terrenas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# res = requests.get(city_url).json()
# res
# city_url

# %%
# res['dt']

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat      Lng  Max Temp  Humidity  \
# 0             bazarnyye mataki  54.8833  49.9333      5.85        87
# 1  edinburgh of the seven seas -37.0676 -12.3116     15.28        67
# 2                 puerto ayora  -0.7393 -90.3518     29.98        93
# 3            port saint john's -31.6229  29.5448     21.01        90
# 4                    colesberg -30.7200  25.0972     14.14        74
#
#    Cloudiness  Wind Speed Country        Date
# 0          58        4.36      RU  1713218142
# 1          23        7.00      SH  1713218142
# 2          93        2.24      EC  1713218142
# 3          99        4.62      ZA  1713218143
# 4         100        3.02      ZA  1713218143

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                   bazarnyye mataki  54.8833  49.9333      5.85        87
# 1        edinburgh of the seven seas -37.0676 -12.3116     15.28        67
# 2                       puerto ayora  -0.7393 -90.3518     29.98        93
# 3                  port saint john's -31.6229  29.5448     21.01        90
# 4                          colesberg -30.7200  25.0972     14.14        74
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                58        4.36      RU  1713218142
# 1                23        7.00      SH  1713218142
# 2                93        2.24      EC  1713218142
# 3                99        4.62      ZA  1713218143
# 4               100        3.02      ZA  1713218143

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Convert 'Date' column to ISO date format  (YYYY-MM-dd)
city_data_df
# city_data_df['Date'] = pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d')
city_data_df['Date'] = pd.to_datetime(city_data_df['Date']).dt.strftime('%Y-%m-%d')

city_data_df.head()
# Find the minimum and maximum dates
min_date = city_data_df['Date'].min()
max_date = city_data_df['Date'].max()

# Print the range of dates
# print("Date Range:", min_date, "to", max_date)
timeDate = max_date
# timeDate

# %%
# Scatter plot for latitude vs. temperature

# Filter the data for the specific date (timeDate)
specific_date_data = city_data_df[city_data_df['Date'] == timeDate]

plt.scatter(specific_date_data['Lat'], specific_date_data['Max Temp'], edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Max Temperature ({timeDate})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Max Temperatur-Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Observation: The scatter plot of Temperature (°C) vs. Latitude plot shown above illustrated temperature peaks at approximately 20-degrees latitude. The latitude values below that latitude show a possible positive linear relationship with temperature, and those above latitude 20 degrees suggest a negative linear relationship with temperature.

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Scatter plot for latitude vs. temperature

# Filter the data for the specific date 
specific_date_data = city_data_df[city_data_df['Date'] == timeDate]

plt.scatter(specific_date_data['Lat'], specific_date_data['Humidity'], edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Humidity ({timeDate})')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Humidity - Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Observation: The Humidity vs. Latitude scatter plot above with data from all cities suggests a relatively spread-out distribution of data points. There seems to be no relationship between humidity and latitude but the humidity percentages seem to largely cluster above 50%.

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Scatter plot for latitude vs. cloudiness

# Filter the data for the specific date (2024-04-11)
specific_date_data = city_data_df[city_data_df['Date'] == timeDate]

plt.scatter(specific_date_data['Lat'], specific_date_data['Cloudiness'], edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Cloudiness ({timeDate})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Cloudiness - Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Observation: The scatter plot on Cloudiness vs. Latitude above, is from data of all the cities. It seems to suggest no relationship between cloudiness and city latitude. Whereas some cloudiness values point to clustering 0, 20, 40, 75, 90, and 100, these values may be rounded or categorized from some of the sources, and thus may not represent continuous variables or measurements.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

# Filter the data for the specific date (2024-04-11)
specific_date_data = city_data_df[city_data_df['Date'] == timeDate]

# Scatter plot for latitude vs. wind speed
plt.scatter(specific_date_data['Lat'], specific_date_data['Wind Speed'], edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Wind Speed ({timeDate})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Wind Speed - Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# #### Observation: The scatter plot on City Wind speed vs. Latitude, seems not to show any relationship between wind speed and latitude but clustering. Most of the wind speed values are below about 6 mps.

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression_plot(x_values, y_values, xlabel, ylabel, title, file_name):
   
    # Function to create a linear regression plot.

    # Parameters:
    # x_values: The values for the x-axis.
    # y_values: The values for the y-axis.
    # xlabel: The label for the x-axis.
    # ylabel: The label for the y-axis.
    # title: The title of the plot.
    # file_name: The file name for saving the plot (optional).

    # Returns:
    # None
   
    # Perform linear regression
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

    # Calculate the regression line
    regress_values = x_values * slope + intercept

    # Create scatter plot
    plt.scatter(x_values, y_values, edgecolors='black', alpha=0.75)

    # Plot regression line
    plt.plot(x_values, regress_values, color='red')

    # Annotate the linear regression equation and correlation coefficient on the plot
    line_eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}\nR² = {round(rvalue**2, 2)}'
    plt.annotate(line_eq, (x_values.min(), y_values.max()), fontsize=12, 
                 color='red', xytext=(20, -320), textcoords='offset points')



    # Set plot labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)

    # Save the figure if has file_name
    if file_name:
        plt.savefig(file_name)

    # Show plot
    plt.show()

# Test
# linear_regression_plot(city_data_df['Lat'], city_data_df['Max Temp'], 'Latitude', 'Max Temperature (°C)', 
#                        'City Latitude vs. Max Temperature Linear Regression', 'output_data/lat_vs_max_temp_regression.png')

# %%
# Create DataFrame for Northern Hemisphere data
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        bazarnyye mataki  54.8833   49.9333      5.85        87          58
# 5            longyearbyen  78.2186   15.6401    -14.09        66          75
# 7                   tiksi  71.6872  128.8694     -4.88        89         100
# 8                ust-nera  64.5667  143.2000    -14.08        81          91
# 9          yuzhno-kurilsk  44.0306  145.8556      5.76        89         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.36      RU  1970-01-01
# 5              4.12      SJ  1970-01-01
# 7              4.58      RU  1970-01-01
# 8              0.94      RU  1970-01-01
# 9              4.11      RU  1970-01-01

# %%
# Create DataFrame for Southern Hemisphere data
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 1        edinburgh of the seven seas -37.0676 -12.3116     15.28        67
# 2                       puerto ayora  -0.7393 -90.3518     29.98        93
# 3                  port saint john's -31.6229  29.5448     21.01        90
# 4                          colesberg -30.7200  25.0972     14.14        74
# 6                  port-aux-francais -49.3500  70.2167      4.59        69
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                23        7.00      SH  1970-01-01
# 2                93        2.24      EC  1970-01-01
# 3                99        4.62      ZA  1970-01-01
# 4               100        3.02      ZA  1970-01-01
# 6                71       17.43      TF  1970-01-01

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Linear regression on Northern Hemisphere for latitude vs. maximum temperature
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Latitude', 'Max Temperature (°C)', 
                       'Northern Hemisphere - City Latitude vs. Max Temperature Linear Regression', 
                       'output_data/northern_hemi_lat_vs_max_temp_regression.png')

# %%
# Linear regression on Southern Hemisphere

# Linear regression on Southern Hemisphere for latitude vs. maximum temperature
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Latitude', 'Max Temperature (°C)', 
                       'Southern Hemisphere - City Latitude vs. Max Temperature Linear Regression', 
                       'output_data/southern_hemi_lat_vs_max_temp_regression.png')

# %% [markdown]
# #### Observation: There is a strong negative correlation (R^2 = 78%) between Max Temperature and Latitude in the Northern hemisphere. The higher the latitude (further from the equator) the cooler it becomes. Conversely, in the Southern hemisphere, there is a moderately positive correlation (R^2 = 56%), here, an increase in latitude (towards the equator) is associated with a moderate increase in temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere for latitude vs. humidity
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 
                       'Humidity (%)', 'Northern Hemisphere - City Latitude vs. Humidity Linear Regression', 
                       'output_data/northern_hemi_lat_vs_humidity_regression.png')

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere for latitude vs. humidity
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 
                       'Humidity (%)', 'Southern Hemisphere - City Latitude vs. Humidity Linear Regression', 
                       'output_data/southern_hemi_lat_vs_humidity_regression.png')

# %% [markdown]
# #### Observation: The correlation coefficent between latitude and humidity in the Northern hemisphere is less than 10% suggesting no relationship between the two, and this was also the finding for cities in the Southern hemisphere. An increase in humidity is not associated with an increase in latitude in the cities. Hence, there is no apparent difference in humidity as you tend towards or away from the equator.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Linear regression on Northern Hemisphere for latitude vs. cloudiness
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Latitude', 
                       'Cloudiness (%)', 'Northern Hemisphere - City Latitude vs. Cloudiness Linear Regression', 
                       'output_data/northern_hemi_lat_vs_cloudiness_regression.png')

# %%
# Southern Hemisphere

# Linear regression on Northern Hemisphere for latitude vs. cloudiness
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Latitude', 
                       'Cloudiness (%)', 'Southern Hemisphere - City Latitude vs. Cloudiness Linear Regression', 
                       'output_data/southern_hemi_lat_vs_cloudiness_regression.png')

# %% [markdown]
# #### Observation: There is no relationship between the latitude of a city in either the Northern or Southern Hemisphere and Cloudiness considering the  r= 1% and r = 3% correlation coefficients,respectively. Thus, lack of difference in cloudiness as you tend towards or away from the equator.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Nothern Hemisphere

# Linear regression on Northern Hemisphere for latitude vs. wind speed
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed (m/s)', 
                       'Northern Hemisphere - City Latitude vs. Wind Speed Linear Regression', 
                       'output_data/northern_hemi_lat_vs_wind_speed_regression.png')

# %%
# Southern Hemisphere

# Linear regression on Northern Hemisphere for latitude vs. wind speed
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed (m/s)', 
                       'Southern Hemisphere - City Latitude vs. Wind Speed Linear Regression', 
                       'output_data/southern_hemi_lat_vs_wind_speed_regression.png')

# %% [markdown]
# #### Observation: There is no relationship between the change in latitude in a city in the Northern Hemisphere and wind speed looking at r = 1%. A very weak negative relationship may exist between latitude and wind speed for cities in the Southern Hemisphere, r=5%. The speed of wind very weakly reduces in the Southern hemisphere as you tend towards the equator.
